# %%
import sys, pprint
pprint.pprint(sys.path)
sys.path.append('/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages') 
sys.path.remove('/usr/local/lib/python3.9/site-packages') 
sys.path.remove( '/usr/local/lib/python3.9/site-packages/IPython/extensions')

# %%
pprint.pprint(sys.path)

# %%
import pandas as pd

# %%
url ="https://finance.yahoo.com/quote/AAPL/history?p=AAPL"

# %%
data=pd.read_html(url,header=0)

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Dec 04, 2020  122.60  122.86  121.52  122.25      122.25   78133200
# 1  Dec 03, 2020  123.52  123.78  122.21  122.94      122.94   78967600
# 2  Dec 02, 2020  122.02  123.37  120.89  123.08      123.08   89004200
# 3  Dec 01, 2020  121.01  123.47  120.01  122.72      122.72  128166800
# 4  Nov 30, 2020  116.97  120.97  116.81  119.05      119.05  169410200

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Jul 24, 2020
# 97                                        Jul 23, 2020
# 98                                        Jul 22, 2020
# 99                                        Jul 21, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                               90.99
# 97                                               97.00
# 98                                               96.69
# 99                                               99.17
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                               92.97
# 97                                               97.08
# 98                                               97.97
# 99                                               99.25
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                               89.14
# 97                                               92.01
# 98                                               96.60
# 99                                               96.74
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 96                                               92.61
# 97                                               92.85
# 98                                               97.27
# 99                                               97.00
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 96                                               92.29
# 97                                               92.52
# 98                                               96.93
# 99                                               96.66
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 96                                           185438800
# 97                                           197004400
# 98                                            89001600
# 99                                           103646000
# 100  *Close price adjusted for splits.**Adjusted cl...

# %%
data[0]["Adj Close**"]=pd.to_numeric(data[0]["Adj Close**"],errors="coerce")

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Jul 24, 2020
# 97                                        Jul 23, 2020
# 98                                        Jul 22, 2020
# 99                                        Jul 21, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                               90.99
# 97                                               97.00
# 98                                               96.69
# 99                                               99.17
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                               92.97
# 97                                               97.08
# 98                                               97.97
# 99                                               99.25
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                               89.14
# 97                                               92.01
# 98                                               96.60
# 99                                               96.74
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  Adj Close**  \
# 96                                               92.61        92.29
# 97                                               92.85        92.52
# 98                                               97.27        96.93
# 99                                               97.00        96.66
# 100  *Close price adjusted for splits.**Adjusted cl...          NaN
#
#                                                 Volume
# 96                                           185438800
# 97                                           197004400
# 98                                            89001600
# 99                                           103646000
# 100  *Close price adjusted for splits.**Adjusted cl...

# %%
data[0].dropna(inplace=True)

# %%
data[0].tail()
# Out:
#             Date   Open   High    Low Close*  Adj Close**     Volume
# 95  Jul 27, 2020  93.71  94.90  93.48  94.81        94.48  121214000
# 96  Jul 24, 2020  90.99  92.97  89.14  92.61        92.29  185438800
# 97  Jul 23, 2020  97.00  97.08  92.01  92.85        92.52  197004400
# 98  Jul 22, 2020  96.69  97.97  96.60  97.27        96.93   89001600
# 99  Jul 21, 2020  99.17  99.25  96.74  97.00        96.66  103646000

# %%
from datetime import datetime as dt

# %%
data[0]["Date2"]=[dt.strptime(i,"%b %d, %Y") for i in data[0]["Date"]]

# %%
data[0]["Date2"].head()
# Out:
# 0   2020-12-04
# 1   2020-12-03
# 2   2020-12-02
# 3   2020-12-01
# 4   2020-11-30
# Name: Date2, dtype: datetime64[ns]

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**     Volume  \
# 0  Dec 04, 2020  122.60  122.86  121.52  122.25       122.25   78133200
# 1  Dec 03, 2020  123.52  123.78  122.21  122.94       122.94   78967600
# 2  Dec 02, 2020  122.02  123.37  120.89  123.08       123.08   89004200
# 3  Dec 01, 2020  121.01  123.47  120.01  122.72       122.72  128166800
# 4  Nov 30, 2020  116.97  120.97  116.81  119.05       119.05  169410200
#
#        Date2
# 0 2020-12-04
# 1 2020-12-03
# 2 2020-12-02
# 3 2020-12-01
# 4 2020-11-30

# %%
data[0].set_index("Date2",inplace=True)

# %%
data[0].head()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2020-12-04  Dec 04, 2020  122.60  122.86  121.52  122.25       122.25
# 2020-12-03  Dec 03, 2020  123.52  123.78  122.21  122.94       122.94
# 2020-12-02  Dec 02, 2020  122.02  123.37  120.89  123.08       123.08
# 2020-12-01  Dec 01, 2020  121.01  123.47  120.01  122.72       122.72
# 2020-11-30  Nov 30, 2020  116.97  120.97  116.81  119.05       119.05
#
#                Volume
# Date2
# 2020-12-04   78133200
# 2020-12-03   78967600
# 2020-12-02   89004200
# 2020-12-01  128166800
# 2020-11-30  169410200

# %%
data[0]["Adj Close**"].dtype
# Out:
# dtype('float64')

# %%
data[0]["Adj Close**"].plot(title="AAPL Stock Price", grid=True)
# Out:
# <AxesSubplot:title={'center':'AAPL Stock Price'}, xlabel='Date2'>

# %%
data[0].to_csv("AAPL_Stock.csv")
