# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.get('https://scraping-for-beginner.herokuapp.com/ranking/')

# %%
elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')

# %%
elem_title=elem_rankingBox.find_element_by_class_name('u_title')
elem_title.text
# Out:
# '1\n観光地 1'

# %%
title=elem_title.text

# %%
title.split('\n')[1]
# Out:
# '観光地 1'

# %%
elem = browser.find_element_by_class_name('u_rankBox')

# %%
elem = elem.find_element_by_class_name('evaluateNumber')

# %% [markdown]
# elem

# %%
elem.text
# Out:
# '4.7'

# %%
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a5821af19d79796321d5b642e88409b4", element="f34f8463-c67d-4ea1-9f39-f9e50f2d708a")>

# %%
elem=browser.find_element_by_class_name('u_categoryTipsItem')

# %%
elem=elem.find_elements_by_class_name('is_rank')[0]

# %%
elem=elem.find_element_by_class_name('evaluateNumber')

# %%
elem.text
# Out:
# '4.6'

# %%
elem=browser.find_element_by_class_name('u_categoryTipsItem')

# %%
elem=elem.find_elements_by_class_name('is_rank')[1]

# %%
elem=elem.find_element_by_class_name('evaluateNumber')

# %%
elem.text
# Out:
# '4.5'

# %%
elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')

# %%
elem_title=elem_rankingBox.find_element_by_class_name('u_title')
elem_title.text
# Out:
# '1\n観光地 1'

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
titles=[]

for elem_rankingBox in elems_rankingBox:
    #elem_rankingBox = elems_rankingBox[1]
    elem_title = elem_rankingBox.find_element_by_class_name('u_title')
    title = elem_title.text.split('\n')[1]
    titles.append(title)

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10']

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_rankBox ')
titles=[]

for elem_rankingBox in elems_rankingBox:
    #elem_rankingBox = elems_rankingBox[1]
    elem_title = elem_rankingBox.find_element_by_class_name('evaluateNumber')
    title = elem_title.text
    titles.append(title)

# %%
titles
# Out:
# ['4.7', '4.7', '4.6', '4.5', '4.5', '4.4', '4.3', '4.3', '4.2', '4.1']

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_categoryTipsItem ')
titles=[]

for elem_rankingBox in elems_rankingBox:
    #elem_rankingBox = elems_rankingBox[1]
    elem_title = elem_rankingBox.find_element_by_class_name('evaluateNumber')
    title = elem_title.text
    titles.append(title)

# %%
titles
# Out:
# ['4.6', '4.6', '4.5', '4.4', '4.4', '4.3', '4.2', '4.2', '4.1', '4.0']

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')

ranks = []
for elem_rank in elems_rank:
    elem_rank = elem_rank.find_element_by_class_name('evaluateNumber')
    rank = float(elem_rank.text)
    ranks.append(rank)

# %%
ranks
# Out:
# [4.7, 4.7, 4.6, 4.5, 4.5, 4.4, 4.3, 4.3, 4.2, 4.1]

# %%
elem = browser.find_element_by_class_name('u_categoryTipsItem')
elem = elem.find_element_by_class_name('is_rank')
elem = elem.find_element_by_class_name('evaluateNumber')
elem.text
# Out:
# '4.6'

# %%
elems = browser.find_elements_by_class_name('u_categoryTipsItem')

categories = []

for elem in elems:
        items = []
        elems_rank = elem.find_elements_by_class_name('is_rank')
        for elem_rank in elems_rank:
            rank = elem_rank.find_element_by_class_name('evaluateNumber').text
            items.append(float(rank))
        categories.append(items)

# %%
categories
# Out:
# [[4.6, 4.5, 4.9, 4.2],
#  [4.6, 4.5, 4.9, 4.2],
#  [4.5, 4.4, 4.8, 4.1],
#  [4.4, 4.4, 4.8, 4.0],
#  [4.4, 4.3, 4.7, 4.0],
#  [4.3, 4.3, 4.7, 3.9],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.1, 4.1, 4.5, 3.7],
#  [4.0, 4.1, 4.4, 3.6]]

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10']

# %%
ranks
# Out:
# [4.7, 4.7, 4.6, 4.5, 4.5, 4.4, 4.3, 4.3, 4.2, 4.1]

# %%
df['観光地名'] =titles
df['総合評価']=ranks

# %%
df
# Out:
#      観光地名  総合評価
# 0   観光地 1   4.7
# 1   観光地 2   4.7
# 2   観光地 3   4.6
# 3   観光地 4   4.5
# 4   観光地 5   4.5
# 5   観光地 6   4.4
# 6   観光地 7   4.3
# 7   観光地 8   4.3
# 8   観光地 9   4.2
# 9  観光地 10   4.1

# %%
categories
# Out:
# [[4.6, 4.5, 4.9, 4.2],
#  [4.6, 4.5, 4.9, 4.2],
#  [4.5, 4.4, 4.8, 4.1],
#  [4.4, 4.4, 4.8, 4.0],
#  [4.4, 4.3, 4.7, 4.0],
#  [4.3, 4.3, 4.7, 3.9],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.1, 4.1, 4.5, 3.7],
#  [4.0, 4.1, 4.4, 3.6]]

# %%
df_categories = pd.DataFrame(categories)
df_categories
# Out:
#      0    1    2    3
# 0  4.6  4.5  4.9  4.2
# 1  4.6  4.5  4.9  4.2
# 2  4.5  4.4  4.8  4.1
# 3  4.4  4.4  4.8  4.0
# 4  4.4  4.3  4.7  4.0
# 5  4.3  4.3  4.7  3.9
# 6  4.2  4.2  4.6  3.8
# 7  4.2  4.2  4.6  3.8
# 8  4.1  4.1  4.5  3.7
# 9  4.0  4.1  4.4  3.6

# %%
df_categories.columns=['楽しさ','人混みの多さ','景色','アクセス']

# %%
pd.concat([df,df_categories],axis=1)
# Out:
#      観光地名  総合評価  楽しさ  人混みの多さ   景色  アクセス
# 0   観光地 1   4.7  4.6     4.5  4.9   4.2
# 1   観光地 2   4.7  4.6     4.5  4.9   4.2
# 2   観光地 3   4.6  4.5     4.4  4.8   4.1
# 3   観光地 4   4.5  4.4     4.4  4.8   4.0
# 4   観光地 5   4.5  4.4     4.3  4.7   4.0
# 5   観光地 6   4.4  4.3     4.3  4.7   3.9
# 6   観光地 7   4.3  4.2     4.2  4.6   3.8
# 7   観光地 8   4.3  4.2     4.2  4.6   3.8
# 8   観光地 9   4.2  4.1     4.1  4.5   3.7
# 9  観光地 10   4.1  4.0     4.1  4.4   3.6

# %%
df.to_csv('観光地情報.csv',index=False)

# %%
df
# Out:
#      観光地名  総合評価
# 0   観光地 1   4.7
# 1   観光地 2   4.7
# 2   観光地 3   4.6
# 3   観光地 4   4.5
# 4   観光地 5   4.5
# 5   観光地 6   4.4
# 6   観光地 7   4.3
# 7   観光地 8   4.3
# 8   観光地 9   4.2
# 9  観光地 10   4.1

# %%
df = pd.concat([df, df_categories], axis=1)

# %%
df
# Out:
#      観光地名  総合評価  楽しさ  人混みの多さ   景色  アクセス
# 0   観光地 1   4.7  4.6     4.5  4.9   4.2
# 1   観光地 2   4.7  4.6     4.5  4.9   4.2
# 2   観光地 3   4.6  4.5     4.4  4.8   4.1
# 3   観光地 4   4.5  4.4     4.4  4.8   4.0
# 4   観光地 5   4.5  4.4     4.3  4.7   4.0
# 5   観光地 6   4.4  4.3     4.3  4.7   3.9
# 6   観光地 7   4.3  4.2     4.2  4.6   3.8
# 7   観光地 8   4.3  4.2     4.2  4.6   3.8
# 8   観光地 9   4.2  4.1     4.1  4.5   3.7
# 9  観光地 10   4.1  4.0     4.1  4.4   3.6

# %%
df.to_csv('観光地情報.csv',index=False)

# %%
titles = []
ranks = []
categories = []

browser = webdriver.Chrome()

for page in range(1,4):

    browser.get('https://scraping-for-beginner.herokuapp.com/ranking/?page={}'.format(page))

    # 観光地名
    elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
    for elem_rankingBox in elems_rankingBox:
        elem_title = elem_rankingBox.find_element_by_class_name('u_title')
        title = elem_title.text.split('\n')[1]
        titles.append(title)

    # 総合評価
    elems_rank = browser.find_elements_by_class_name('u_rankBox')
    for elem_rank in elems_rank:
        elem_rank = elem_rank.find_element_by_class_name('evaluateNumber')
        rank = float(elem_rank.text)
        ranks.append(rank)

    # 各項目
    elems = browser.find_elements_by_class_name('u_categoryTipsItem')
    for elem in elems:
            items = []
            elems_rank = elem.find_elements_by_class_name('is_rank')
            for elem_rank in elems_rank:
                rank = elem_rank.find_element_by_class_name('evaluateNumber').text
                items.append(rank)
            categories.append(items)

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10',
#  '観光地 11',
#  '観光地 12',
#  '観光地 13',
#  '観光地 14',
#  '観光地 15',
#  '観光地 16',
#  '観光地 17',
#  '観光地 18',
#  '観光地 19',
#  '観光地 20',
#  '観光地 21',
#  '観光地 22',
#  '観光地 23',
#  '観光地 24',
#  '観光地 25',
#  '観光地 26',
#  '観光地 27',
#  '観光地 28',
#  '観光地 29',
#  '観光地 30']

# %%
df = pd.DataFrame()

# %%
df['観光地名'] =titles
df['総合評価']=ranks

# %%
df
# Out:
#       観光地名  総合評価
# 0    観光地 1   4.7
# 1    観光地 2   4.7
# 2    観光地 3   4.6
# 3    観光地 4   4.5
# 4    観光地 5   4.5
# 5    観光地 6   4.4
# 6    観光地 7   4.3
# 7    観光地 8   4.3
# 8    観光地 9   4.2
# 9   観光地 10   4.1
# 10  観光地 11   4.1
# 11  観光地 12   4.0
# 12  観光地 13   3.9
# 13  観光地 14   3.9
# 14  観光地 15   3.8
# 15  観光地 16   3.7
# 16  観光地 17   3.7
# 17  観光地 18   3.6
# 18  観光地 19   3.5
# 19  観光地 20   3.5
# 20  観光地 21   3.4
# 21  観光地 22   3.3
# 22  観光地 23   3.3
# 23  観光地 24   3.2
# 24  観光地 25   3.1
# 25  観光地 26   3.1
# 26  観光地 27   3.0
# 27  観光地 28   2.9
# 28  観光地 29   2.9
# 29  観光地 30   2.8

# %%
df_categories = pd.DataFrame(categories)
df_categories
# Out:
#       0    1    2    3
# 0   4.6  4.5  4.9  4.2
# 1   4.6  4.5  4.9  4.2
# 2   4.5  4.4  4.8  4.1
# 3   4.4  4.4  4.8  4.0
# 4   4.4  4.3  4.7  4.0
# 5   4.3  4.3  4.7  3.9
# 6   4.2  4.2  4.6  3.8
# 7   4.2  4.2  4.6  3.8
# 8   4.1  4.1  4.5  3.7
# 9   4.0  4.1  4.4  3.6
# 10  4.0  4.0  4.4  3.6
# 11  3.9  4.0  4.3  3.5
# 12  3.8  3.9  4.3  3.4
# 13  3.8  3.9  4.2  3.4
# 14  3.7  3.8  4.2  3.3
# 15  3.6  3.8  4.1  3.2
# 16  3.6  3.7  4.1  3.2
# 17  3.5  3.7  4.0  3.1
# 18  3.4  3.6  3.9  3.0
# 19  3.4  3.6  3.9  3.0
# 20  3.3  3.5  3.8  2.9
# 21  3.2  3.5  3.8  2.8
# 22  3.2  3.4  3.7  2.8
# 23  3.1  3.4  3.7  2.7
# 24  3.0  3.3  3.6  2.6
# 25  3.0  3.3  3.6  2.6
# 26  2.9  3.2  3.5  2.5
# 27  2.8  3.2  3.4  2.4
# 28  2.8  3.1  3.4  2.4
# 29  2.7  3.1  3.3  2.3

# %%
df_categories.columns=['楽しさ','人混みの多さ','景色','アクセス']

# %%
df =pd.concat([df,df_categories],axis=1)

# %%
df
# Out:
#       観光地名  総合評価  楽しさ 人混みの多さ   景色 アクセス
# 0    観光地 1   4.7  4.6    4.5  4.9  4.2
# 1    観光地 2   4.7  4.6    4.5  4.9  4.2
# 2    観光地 3   4.6  4.5    4.4  4.8  4.1
# 3    観光地 4   4.5  4.4    4.4  4.8  4.0
# 4    観光地 5   4.5  4.4    4.3  4.7  4.0
# 5    観光地 6   4.4  4.3    4.3  4.7  3.9
# 6    観光地 7   4.3  4.2    4.2  4.6  3.8
# 7    観光地 8   4.3  4.2    4.2  4.6  3.8
# 8    観光地 9   4.2  4.1    4.1  4.5  3.7
# 9   観光地 10   4.1  4.0    4.1  4.4  3.6
# 10  観光地 11   4.1  4.0    4.0  4.4  3.6
# 11  観光地 12   4.0  3.9    4.0  4.3  3.5
# 12  観光地 13   3.9  3.8    3.9  4.3  3.4
# 13  観光地 14   3.9  3.8    3.9  4.2  3.4
# 14  観光地 15   3.8  3.7    3.8  4.2  3.3
# 15  観光地 16   3.7  3.6    3.8  4.1  3.2
# 16  観光地 17   3.7  3.6    3.7  4.1  3.2
# 17  観光地 18   3.6  3.5    3.7  4.0  3.1
# 18  観光地 19   3.5  3.4    3.6  3.9  3.0
# 19  観光地 20   3.5  3.4    3.6  3.9  3.0
# 20  観光地 21   3.4  3.3    3.5  3.8  2.9
# 21  観光地 22   3.3  3.2    3.5  3.8  2.8
# 22  観光地 23   3.3  3.2    3.4  3.7  2.8
# 23  観光地 24   3.2  3.1    3.4  3.7  2.7
# 24  観光地 25   3.1  3.0    3.3  3.6  2.6
# 25  観光地 26   3.1  3.0    3.3  3.6  2.6
# 26  観光地 27   3.0  2.9    3.2  3.5  2.5
# 27  観光地 28   2.9  2.8    3.2  3.4  2.4
# 28  観光地 29   2.9  2.8    3.1  3.4  2.4
# 29  観光地 30   2.8  2.7    3.1  3.3  2.3

# %%
df.to_csv('観光地情報.csv',index=False)
